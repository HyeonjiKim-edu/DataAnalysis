# %% [markdown]
# <a href="https://colab.research.google.com/github/yleessam/datascience/blob/main/20%EC%B0%A8%EC%8B%9C_%ED%8C%8C%EC%9D%B4%EC%8D%AC%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 파이썬 데이터분석 실습

# %% [markdown]
# # 순서
# 0. 데이터 확인
# 1. 필요 라이브러리 임포트 및 파일 읽어오기
# 2. EDA 탐색적 데이터 분석
# 3. 데이터 전처리 수행
#  - 필요한 컬럼 정리
#  - 컬럼 데이터 정제
#  - Null 처리
#  - 컬럼 type 변경하기
# 4. 데이터 시각화
# 5. 결과 저장

# %% [markdown]
# # #0. 데이터의 확인

# %% [markdown]
# https://survey.keis.or.kr/goms/gomsdownload/List.jsp
#
# - **행정동별 주민등록 인구 및 세대현황**
# - 거주지의 인구 구조 시각화를 통한 인구 현황 분석
# - 인구증가율, 인구밀도 분석 및 도시화 현황 분석
# - 사회, 경제, 정책, 건강 등 여러 분야에 적용할 수 있는 인사이트를 도출 조사

# %% [markdown]
# # #1. 필요 라이브러리 임포트 및 파일 읽어오기

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# ## CSV 파일 데이터 읽어오기

# %%
df = pd.read_csv('./data/202404_202409_연령별인구현황_월간.csv', encoding='cp949')

# %%
# 읽어온 데이터프레임 확인하기
df
# Out:
#                      행정구역 2024년04월_계_총인구수 2024년04월_계_연령구간인구수  \
# 0        전국  (0000000000)      51,285,153         29,258,198
# 1     서울특별시  (1100000000)       9,378,269          5,678,677
# 2     부산광역시  (2600000000)       3,284,947          1,781,294
# 3     대구광역시  (2700000000)       2,368,670          1,328,607
# 4     인천광역시  (2800000000)       3,008,484          1,773,484
# 5     광주광역시  (2900000000)       1,414,862            828,352
# 6     대전광역시  (3000000000)       1,441,272            847,717
# 7     울산광역시  (3100000000)       1,101,059            637,631
# 8   세종특별자치시  (3600000000)         387,726            229,178
# 9       경기도  (4100000000)      13,648,156          8,135,078
# 10  강원특별자치도  (5100000000)       1,523,661            786,288
# 11     충청북도  (4300000000)       1,590,854            867,311
# 12     충청남도  (4400000000)       2,133,828          1,149,839
# 13  전북특별자치도  (5200000000)       1,748,047            903,002
# ...

# %% [markdown]
# # #2. 탐색적 데이터 분석

# %% [markdown]
# ## 데이터 탐색하기

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Columns: 109 entries, 행정구역 to 2024년09월_여_50~59세
# dtypes: object(109)
# memory usage: 15.5+ KB

# %%
df.shape
# Out:
# (18, 109)

# %%
df.head(3)
# Out:
#                   행정구역 2024년04월_계_총인구수 2024년04월_계_연령구간인구수 2024년04월_계_20~29세  \
# 0     전국  (0000000000)      51,285,153         29,258,198         6,110,713
# 1  서울특별시  (1100000000)       9,378,269          5,678,677         1,345,398
# 2  부산광역시  (2600000000)       3,284,947          1,781,294           370,874
#
#   2024년04월_계_30~39세 2024년04월_계_40~49세 2024년04월_계_50~59세 2024년04월_남_총인구수  \
# 0         6,573,833         7,847,315         8,726,337      25,541,855
# 1         1,429,039         1,407,189         1,497,051       4,532,115
# 2           389,467           479,849           541,104       1,600,234
#
#   2024년04월_남_연령구간인구수 2024년04월_남_20~29세  ... 2024년09월_남_20~29세  \
# 0         15,004,634         3,188,391  ...         3,135,248
# 1          2,783,266           636,314  ...           624,025
# 2            897,925           190,213  ...           186,053
#
#   2024년09월_남_30~39세 2024년09월_남_40~49세 2024년09월_남_50~59세 2024년09월_여_총인구수  \
# ...

# %% [markdown]
# ## 자료구조 파악

# %%
df.describe()
# Out:
#                     행정구역 2024년04월_계_총인구수 2024년04월_계_연령구간인구수 2024년04월_계_20~29세  \
# count                 18              18                 18                18
# unique                18              18                 18                18
# top     전국  (0000000000)      51,285,153         29,258,198         6,110,713
# freq                   1               1                  1                 1
#
#        2024년04월_계_30~39세 2024년04월_계_40~49세 2024년04월_계_50~59세 2024년04월_남_총인구수  \
# count                 18                18                18              18
# unique                18                18                18              18
# top            6,573,833         7,847,315         8,726,337      25,541,855
# freq                   1                 1                 1               1
#
#        2024년04월_남_연령구간인구수 2024년04월_남_20~29세  ... 2024년09월_남_20~29세  \
# count                  18                18  ...                18
# ...

# %% [markdown]
# ## 데이터 타입, 인덱스, 컬럼명, Values 확인

# %%
df.columns
# Out:
# Index(['행정구역', '2024년04월_계_총인구수', '2024년04월_계_연령구간인구수', '2024년04월_계_20~29세',
#        '2024년04월_계_30~39세', '2024년04월_계_40~49세', '2024년04월_계_50~59세',
#        '2024년04월_남_총인구수', '2024년04월_남_연령구간인구수', '2024년04월_남_20~29세',
#        ...
#        '2024년09월_남_20~29세', '2024년09월_남_30~39세', '2024년09월_남_40~49세',
#        '2024년09월_남_50~59세', '2024년09월_여_총인구수', '2024년09월_여_연령구간인구수',
#        '2024년09월_여_20~29세', '2024년09월_여_30~39세', '2024년09월_여_40~49세',
#        '2024년09월_여_50~59세'],
#       dtype='object', length=109)

# %%
df['행정구역']
# Out:
# 0          전국  (0000000000)
# 1       서울특별시  (1100000000)
# 2       부산광역시  (2600000000)
# 3       대구광역시  (2700000000)
# 4       인천광역시  (2800000000)
# 5       광주광역시  (2900000000)
# 6       대전광역시  (3000000000)
# 7       울산광역시  (3100000000)
# 8     세종특별자치시  (3600000000)
# 9         경기도  (4100000000)
# 10    강원특별자치도  (5100000000)
# 11       충청북도  (4300000000)
# 12       충청남도  (4400000000)
# 13    전북특별자치도  (5200000000)
# 14       전라남도  (4600000000)
# 15       경상북도  (4700000000)
# 16       경상남도  (4800000000)
# 17    제주특별자치도  (5000000000)
# Name: 행정구역, dtype: object

# %%
df.dtypes
# Out:
# 행정구역                  object
# 2024년04월_계_총인구수       object
# 2024년04월_계_연령구간인구수    object
# 2024년04월_계_20~29세     object
# 2024년04월_계_30~39세     object
#                        ...
# 2024년09월_여_연령구간인구수    object
# 2024년09월_여_20~29세     object
# 2024년09월_여_30~39세     object
# 2024년09월_여_40~49세     object
# 2024년09월_여_50~59세     object
# Length: 109, dtype: object

# %%
# 행정구역 데이터 간소화(데이터명 변경)
df['행정구역'] = df['행정구역'].str.replace(r'\s*\(.*\)', '', regex=True)
df['행정구역']
# Out:
# 0          전국
# 1       서울특별시
# 2       부산광역시
# 3       대구광역시
# 4       인천광역시
# 5       광주광역시
# 6       대전광역시
# 7       울산광역시
# 8     세종특별자치시
# 9         경기도
# 10    강원특별자치도
# 11       충청북도
# 12       충청남도
# 13    전북특별자치도
# 14       전라남도
# 15       경상북도
# 16       경상남도
# 17    제주특별자치도
# Name: 행정구역, dtype: object

# %% [markdown]
# ## Null 데이터 확인

# %%
df.isnull().sum()
# Out:
# 행정구역                  0
# 2024년04월_계_총인구수       0
# 2024년04월_계_연령구간인구수    0
# 2024년04월_계_20~29세     0
# 2024년04월_계_30~39세     0
#                      ..
# 2024년09월_여_연령구간인구수    0
# 2024년09월_여_20~29세     0
# 2024년09월_여_30~39세     0
# 2024년09월_여_40~49세     0
# 2024년09월_여_50~59세     0
# Length: 109, dtype: int64

# %% [markdown]
# # #3. 데이터 전처리 수행

# %% [markdown]
# ## 컬럼 내용 변경하기

# %% [markdown]
# - 수치형 데이터로 변환 및 출력

# %%
# 인덱스열 제외한 데이터열 묶기
convert_num = df.columns.difference(['행정구역'])

# 해당 데이터열의 콤마 제거 후 숫자로 변환
df[convert_num] = df[convert_num].replace(',', '', regex=True).apply(pd.to_numeric, errors='coerce').astype(int)

# %%
df.dtypes
# Out:
# 행정구역                  object
# 2024년04월_계_총인구수        int32
# 2024년04월_계_연령구간인구수     int32
# 2024년04월_계_20~29세      int32
# 2024년04월_계_30~39세      int32
#                        ...
# 2024년09월_여_연령구간인구수     int32
# 2024년09월_여_20~29세      int32
# 2024년09월_여_30~39세      int32
# 2024년09월_여_40~49세      int32
# 2024년09월_여_50~59세      int32
# Length: 109, dtype: object

# %%
# 지수 표기법 대신 일반 숫자 형식으로 출력 설정
pd.options.display.float_format = '{:.0f}'.format  # 정수로 표시

# describe 출력
df.describe()
# Out:
#        2024년04월_계_총인구수  2024년04월_계_연령구간인구수  2024년04월_계_20~29세  \
# count               18                  18                 18
# mean           5698350             3250911             678968
# std           11841907             6788228            1422160
# min             387726              229178              37365
# 25%            1461869              833193             175334
# 50%            1965514             1026420             210602
# 75%            3181539             1766545             348820
# max           51285153            29258198            6110713
#
#        2024년04월_계_30~39세  2024년04월_계_40~49세  2024년04월_계_50~59세  \
# count                 18                 18                 18
# mean              730426             871924             969593
# std              1535132            1820005            2013287
# min                59017              77254              55542
# 25%               169381             219211             248896
# ...

# %%
df.head(3)
# Out:
#     행정구역  2024년04월_계_총인구수  2024년04월_계_연령구간인구수  2024년04월_계_20~29세  \
# 0     전국         51285153            29258198            6110713
# 1  서울특별시          9378269             5678677            1345398
# 2  부산광역시          3284947             1781294             370874
#
#    2024년04월_계_30~39세  2024년04월_계_40~49세  2024년04월_계_50~59세  2024년04월_남_총인구수  \
# 0            6573833            7847315            8726337         25541855
# 1            1429039            1407189            1497051          4532115
# 2             389467             479849             541104          1600234
#
#    2024년04월_남_연령구간인구수  2024년04월_남_20~29세  ...  2024년09월_남_20~29세  \
# 0            15004634            3188391  ...            3135248
# 1             2783266             636314  ...             624025
# 2              897925             190213  ...             186053
#
#    2024년09월_남_30~39세  2024년09월_남_40~49세  2024년09월_남_50~59세  2024년09월_여_총인구수  \
# ...

# %% [markdown]
# ## Null 데이터 확인

# %%
df.isnull().sum()
# Out:
# 행정구역                  0
# 2024년04월_계_총인구수       0
# 2024년04월_계_연령구간인구수    0
# 2024년04월_계_20~29세     0
# 2024년04월_계_30~39세     0
#                      ..
# 2024년09월_여_연령구간인구수    0
# 2024년09월_여_20~29세     0
# 2024년09월_여_30~39세     0
# 2024년09월_여_40~49세     0
# 2024년09월_여_50~59세     0
# Length: 109, dtype: int64

# %% [markdown]
# # #4. 기술통계

# %% [markdown]
# ## 4-1. 현황 분석

# %% [markdown]
# ### 분석 대상 인원 규모

# %%
# 총 인구수 대비 분석 대상 인원의 비율
subjects = df[['2024년09월_계_연령구간인구수', '2024년09월_계_총인구수']].copy()
subjects['인구비율'] = (subjects['2024년09월_계_연령구간인구수'] / subjects['2024년09월_계_총인구수']) * 100
subjects.index = df['행정구역']
subjects
# Out:
#          2024년09월_계_연령구간인구수  2024년09월_계_총인구수  인구비율
# 행정구역
# 전국                 29119178         51248233    57
# 서울특별시               5645704          9350995    60
# 부산광역시               1766448          3273473    54
# 대구광역시               1320047          2365523    56
# 인천광역시               1769574          3016520    59
# 광주광역시                822979          1411357    58
# 대전광역시                844677          1440456    59
# 울산광역시                632715          1098728    58
# 세종특별자치시              229806           389443    59
# 경기도                 8121644         13680645    59
# 강원특별자치도              780420          1520410    51
# 충청북도                 864528          1590858    54
# 충청남도                1146753          2135373    54
# 전북특별자치도              895271          1741640    51
# 전라남도                 884294          1791496    49
# 경상북도                1286027          2537955    51
# 경상남도                1734310          3232297    54
# ...

# %%
print(subjects.dtypes)
# Out:
# 2024년09월_계_연령구간인구수      int32
# 2024년09월_계_총인구수         int32
# 인구비율                  float64
# dtype: object

# %% [markdown]
# ### 성비 확인

# %%
# 전체 성인 성비 확인 

all_s = df[['2024년09월_남_연령구간인구수', '2024년09월_여_연령구간인구수']].copy()
all_s['성인 남성 인구 비율'] = all_s['2024년09월_남_연령구간인구수'] / (all_s['2024년09월_남_연령구간인구수'] + all_s['2024년09월_여_연령구간인구수']) * 100
all_s['성인 여성 인구 비율'] = all_s['2024년09월_여_연령구간인구수'] / (all_s['2024년09월_남_연령구간인구수'] + all_s['2024년09월_여_연령구간인구수']) * 100
all_s.index = df['행정구역']
all_s
# Out:
#          2024년09월_남_연령구간인구수  2024년09월_여_연령구간인구수  성인 남성 인구 비율  성인 여성 인구 비율
# 행정구역
# 전국                 14932319            14186859           51           49
# 서울특별시               2765271             2880433           49           51
# 부산광역시                890608              875840           50           50
# 대구광역시                670096              649951           51           49
# 인천광역시                906025              863549           51           49
# 광주광역시                417074              405905           51           49
# 대전광역시                432092              412585           51           49
# 울산광역시                334417              298298           53           47
# 세종특별자치시              115477              114329           50           50
# 경기도                 4175634             3946010           51           49
# 강원특별자치도              411184              369236           53           47
# 충청북도                 459166              405362           53           47
# ...

# %% [markdown]
# ### 연령대 분포 확인

# %%
# 전체 성인 연령대 비율 확인

all_a = df[['2024년09월_계_연령구간인구수', '2024년09월_계_20~29세', '2024년09월_계_30~39세', '2024년09월_계_40~49세', '2024년09월_계_50~59세']].copy()
all_a.index = df['행정구역']
all_a
# Out:
#          2024년09월_계_연령구간인구수  2024년09월_계_20~29세  2024년09월_계_30~39세  \
# 행정구역
# 전국                 29119178            6017023            6610361
# 서울특별시               5645704            1323486            1438253
# 부산광역시               1766448             363392             389693
# 대구광역시               1320047             271395             282259
# 인천광역시               1769574             354874             420164
# 광주광역시                822979             184342             173792
# 대전광역시                844677             195439             190021
# 울산광역시                632715             118259             136479
# 세종특별자치시              229806              37073              59007
# 경기도                 8121644            1640878            1898714
# 강원특별자치도              780420             157920             158364
# 충청북도                 864528             175684             188572
# 충청남도                1146753             221480             251738
# ...

# %% [markdown]
# ### 지역별 분포 확인

# %%
# 전체 지역별 인구분포

all_r = df['2024년09월_계_연령구간인구수']
all_r.index = df['행정구역']
all_r
# Out:
# 행정구역
# 전국         29119178
# 서울특별시       5645704
# 부산광역시       1766448
# 대구광역시       1320047
# 인천광역시       1769574
# 광주광역시        822979
# 대전광역시        844677
# 울산광역시        632715
# 세종특별자치시      229806
# 경기도         8121644
# 강원특별자치도      780420
# 충청북도         864528
# 충청남도        1146753
# 전북특별자치도      895271
# 전라남도         884294
# 경상북도        1286027
# 경상남도        1734310
# 제주특별자치도      373981
# Name: 2024년09월_계_연령구간인구수, dtype: int32

# %% [markdown]
# ## 4-2. 종단적 분석

# %% [markdown]
# ### 6개월간 지역별 인구 변동 추이

# %%
# 지역별 인구 변동 추이 확인(6개월)
period_r = df[['2024년09월_계_연령구간인구수', '2024년08월_계_연령구간인구수', '2024년07월_계_연령구간인구수', '2024년06월_계_연령구간인구수', '2024년05월_계_연령구간인구수', '2024년04월_계_연령구간인구수']]
period_r.index = df['행정구역']
period_r
# Out:
#          2024년09월_계_연령구간인구수  2024년08월_계_연령구간인구수  2024년07월_계_연령구간인구수  \
# 행정구역
# 전국                 29119178            29147777            29180116
# 서울특별시               5645704             5652252             5658784
# 부산광역시               1766448             1769304             1772631
# 대구광역시               1320047             1321775             1323507
# 인천광역시               1769574             1770341             1771280
# 광주광역시                822979              824022              825272
# 대전광역시                844677              844863              845430
# 울산광역시                632715              633675              634849
# 세종특별자치시              229806              229885              229629
# 경기도                 8121644             8124723             8128825
# 강원특별자치도              780420              781506              782953
# 충청북도                 864528              865131              866217
# 충청남도                1146753             1147518             1148573
# ...

# %%
# 참고 : 데이터 프레임 형성해주는 함수
def get_population_data(df, cols, index_col='행정구역', calc_ratio=None):
    data = df[cols].copy()
    
    # 인덱스를 설정
    if index_col:
        data.index = df[index_col]
        
    # 비율 계산이 필요한 경우
    if calc_ratio:
        numerator, denominator = calc_ratio
        data['비율'] = (data[numerator] / data[denominator]) * 100
    
    return data

# %% [markdown]
# # #5. 시각화

# %% [markdown]
# ## 라이브러리 임포트

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Bar 차트

# %%
fig = plt.figure(figsize=(16,5))

# 총인구 대비 연령구간 인구 비율
# subjects['전국'], bar

# %% [markdown]
# ## 숫자형 컬럼에 대한 시각화

# %% [markdown]
# ## Histgram

# %%
# seaborn 라이브러리 임포트
#!pip install seaborn

import seaborn as sns

# %% [markdown]
# - tenure 컬럼

# %% [markdown]
# - TotalCharges 컬럼

# %% [markdown]
# ## Countplot

# %% [markdown]
# ## heatmap

# %% [markdown]
# ## boxplot

# %% [markdown]
# # # 6. 결과 저장하기

# %% [markdown]
# ## 결과를 csv 파일로 저장하기

# %% [markdown]
# # #X. 랩업
# 1. 필요 라이브러리 임포트 및 파일 읽어오기 : pd.read_csv()
# 2. EDA (Exploratory Data Analysis) 탐색적 데이터 분석 : df.info(), df.head(), df.tail()
# 3. 데이터 전처리 수행
#  + 불필요 컬럼 삭제 : df.drop()
#  + 컬럼 내용 변경하기 : df.replace()
#  + Null 처리 : df.replace(), df.fillna()
#  + 컬럼 type 변경하기 : df['col'].astype(int)
# 4. 시각화
#  + matplotlib, seaborn
#  + bar, scatter, countplot, boxplot
# 5. 결과 저장하기
#  + to_csv()
